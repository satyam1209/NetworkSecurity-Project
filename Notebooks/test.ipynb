# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Test\Desktop\Flask\ML\networksecurity\Network_Data\phisingData.csv')
# df.info()
len(df.select_dtypes(include=['int64', 'float64']).columns)
# Out:
# 31
